# %% [markdown]
# <a href="https://colab.research.google.com/github/Rupesvedak24/First/blob/main/1_Neural_Network_Back_Propagation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow

# %%
# !pip install keras

# %%
# Create your first MLP in Keras
from keras.models import Sequential
from keras.layers import Dense
import numpy

# %%
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load pima indians dataset
dataset = numpy.loadtxt("/content/pima-indians-diabetes.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# %%
# create model
model = Sequential()
model.add(Dense(12, input_dim=8,  activation='relu'))
model.add(Dense(8,  activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Fit the model
model.fit(X, Y, validation_split=0.33, epochs=250, batch_size=20)
# Out:
# Epoch 1/250
# 26/26 [==============================] - 14s 21ms/step - loss: 16.6415 - accuracy: 0.3628 - val_loss: 10.6027 - val_accuracy: 0.4134
# Epoch 2/250
# 26/26 [==============================] - 0s 2ms/step - loss: 10.0399 - accuracy: 0.3598 - val_loss: 6.2928 - val_accuracy: 0.4882
# Epoch 3/250
# 26/26 [==============================] - 0s 2ms/step - loss: 5.7234 - accuracy: 0.5053 - val_loss: 4.5183 - val_accuracy: 0.5472
# Epoch 4/250
# 26/26 [==============================] - 0s 3ms/step - loss: 4.5426 - accuracy: 0.5235 - val_loss: 3.4539 - val_accuracy: 0.5512
# Epoch 5/250
# 26/26 [==============================] - 0s 2ms/step - loss: 3.7110 - accuracy: 0.5352 - val_loss: 2.3026 - val_accuracy: 0.5669
# Epoch 6/250
# 26/26 [==============================] - 0s 2ms/step - loss: 2.2601 - accuracy: 0.5099 - val_loss: 1.5025 - val_accuracy: 0.5118
# Epoch 7/250
# ...

# %%
# evaluate the model
scores = model.evaluate(X, Y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5466 - accuracy: 0.7669
# accuracy: 76.69%
