# %% [markdown]
# <a href="https://colab.research.google.com/github/Rupesvedak24/First/blob/main/2_NN_Hyperparameter_Tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing the necessary packages
import pandas as pd
import numpy as np
import keras
from sklearn.preprocessing import StandardScaler

# %%
# load pima indians dataset
dataset = np.loadtxt("pima-indians-diabetes.csv", delimiter=",")

# %%
X = dataset[:,0:8]
y = dataset[:,8]

# %%
# Standardization
a = StandardScaler()
a.fit(X)
X_standardized = a.transform(X)

# %%
pd.DataFrame(X_standardized).describe()
# Out:
#                   0             1  ...             6             7
# count  7.680000e+02  7.680000e+02  ...  7.680000e+02  7.680000e+02
# mean  -7.748432e-17  3.614007e-18  ...  1.924387e-15  2.192980e-16
# std    1.000652e+00  1.000652e+00  ...  1.000652e+00  1.000652e+00
# min   -1.141852e+00 -3.783654e+00  ... -1.189553e+00 -1.041549e+00
# 25%   -8.448851e-01 -6.852363e-01  ... -6.889685e-01 -7.862862e-01
# 50%   -2.509521e-01 -1.218877e-01  ... -3.001282e-01 -3.608474e-01
# 75%    6.399473e-01  6.057709e-01  ...  4.662269e-01  6.602056e-01
# max    3.906578e+00  2.444478e+00  ...  5.883565e+00  4.063716e+00
#
# [8 rows x 8 columns]

# %% [markdown]
# #### Tuning of Hyperparameters :- Batch Size and Epochs

# %%
# Importing the necessary packages
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam

# %%
# create model
def create_model():
    model = Sequential()
    model.add(Dense(12, input_dim=8, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
    
    adam=Adam(learning_rate=0.01)
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    return model

# %%
# Create the model
model = KerasClassifier(build_fn = create_model,verbose = 0)
# Define the grid search parameters
batch_size = [10,20,40]
epochs = [10,50,100]
# Make a dictionary of the grid search parameters
param_grid = dict(batch_size = batch_size,epochs = epochs)
# Build and fit the GridSearchCV
grid = GridSearchCV(estimator = model,param_grid = param_grid,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ............ batch_size=10, epochs=10, score=0.753, total=  15.5s
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   15.5s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=10, score=0.721, total=   1.7s
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   17.2s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=10, score=0.760, total=   1.7s
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   19.0s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=10, score=0.850, total=   1.7s
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   20.7s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=10, score=0.771, total=   2.0s
# [CV] batch_size=10, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   22.6s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=50, score=0.753, total=   6.2s
# [CV] batch_size=10, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   28.8s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=50, score=0.662, total=   6.2s
# [CV] batch_size=10, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   35.0s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=50, score=0.734, total=   6.2s
# [CV] batch_size=10, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   41.2s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=50, score=0.797, total=   6.2s
# [CV] batch_size=10, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   47.4s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=50, score=0.758, total=   6.2s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ........... batch_size=10, epochs=100, score=0.714, total=  11.3s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ........... batch_size=10, epochs=100, score=0.701, total=  11.3s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ........... batch_size=10, epochs=100, score=0.708, total=   6.8s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ........... batch_size=10, epochs=100, score=0.804, total=  11.7s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ........... batch_size=10, epochs=100, score=0.758, total=   6.9s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.760, total=   1.4s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.721, total=   1.4s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.760, total=   1.7s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.850, total=   1.7s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.771, total=   1.4s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] ............ batch_size=20, epochs=50, score=0.760, total=   3.6s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] ............ batch_size=20, epochs=50, score=0.708, total=   3.6s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] ............ batch_size=20, epochs=50, score=0.753, total=   2.7s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] ............ batch_size=20, epochs=50, score=0.791, total=   3.1s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] ............ batch_size=20, epochs=50, score=0.797, total=   2.6s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ........... batch_size=20, epochs=100, score=0.727, total=   4.1s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ........... batch_size=20, epochs=100, score=0.669, total=   6.2s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ........... batch_size=20, epochs=100, score=0.753, total=   4.2s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ........... batch_size=20, epochs=100, score=0.732, total=   6.2s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ........... batch_size=20, epochs=100, score=0.784, total=   4.2s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] ............ batch_size=40, epochs=10, score=0.753, total=   1.4s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] ............ batch_size=40, epochs=10, score=0.708, total=   1.4s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] ............ batch_size=40, epochs=10, score=0.760, total=   1.7s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] ............ batch_size=40, epochs=10, score=0.843, total=   1.4s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] ............ batch_size=40, epochs=10, score=0.752, total=   1.3s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] ............ batch_size=40, epochs=50, score=0.740, total=   2.4s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] ............ batch_size=40, epochs=50, score=0.721, total=   2.4s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] ............ batch_size=40, epochs=50, score=0.766, total=   2.4s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] ............ batch_size=40, epochs=50, score=0.830, total=   1.9s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] ............ batch_size=40, epochs=50, score=0.765, total=   1.9s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ........... batch_size=40, epochs=100, score=0.734, total=   2.8s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ........... batch_size=40, epochs=100, score=0.682, total=   3.3s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ........... batch_size=40, epochs=100, score=0.760, total=   2.8s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ........... batch_size=40, epochs=100, score=0.804, total=   3.7s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ........... batch_size=40, epochs=100, score=0.778, total=   3.7s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:  3.1min finished

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7722349524497986, using {'batch_size': 20, 'epochs': 10}
# 0.7709362506866455,0.042786909774775964 with: {'batch_size': 10, 'epochs': 10}
# 0.7409812450408936,0.044416703840043266 with: {'batch_size': 10, 'epochs': 50}
# 0.7370936393737793,0.03891075667756195 with: {'batch_size': 10, 'epochs': 100}
# 0.7722349524497986,0.04232634304699133 with: {'batch_size': 20, 'epochs': 10}
# 0.7618028998374939,0.03195140891943079 with: {'batch_size': 20, 'epochs': 50}
# 0.733138108253479,0.03793236822165346 with: {'batch_size': 20, 'epochs': 100}
# 0.763110089302063,0.0440562313315171 with: {'batch_size': 40, 'epochs': 10}
# 0.764408802986145,0.036880667353967694 with: {'batch_size': 40, 'epochs': 50}
# 0.7514048099517823,0.04165679096751558 with: {'batch_size': 40, 'epochs': 100}

# %% [markdown]
# #### Tuning of Hyperparameters:- Learning rate and Drop out rate

# %%
from keras.layers import Dropout

# Defining the model

def create_model(learning_rate,dropout_rate):
    model = Sequential()
    model.add(Dense(8,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(4,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = learning_rate)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 10,epochs = 10)

# Define the grid search parameters

learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]

# Make a dictionary of the grid search parameters

param_grids = dict(learning_rate = learning_rate,dropout_rate = dropout_rate)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.760, total=   2.4s
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.714, total=   2.6s
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.9s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.753, total=   1.8s
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    6.8s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.830, total=   2.2s
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    9.0s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.778, total=   1.8s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   10.7s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.740, total=   1.9s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   12.6s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.708, total=   1.8s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   14.5s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.753, total=   1.8s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   16.2s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.810, total=   1.8s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   18.0s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.784, total=   1.7s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.701, total=   1.8s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.662, total=   1.7s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.747, total=   2.2s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.771, total=   1.7s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.778, total=   1.8s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.747, total=   1.8s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.721, total=   1.9s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.753, total=   1.9s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.837, total=   1.9s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.765, total=   1.9s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.721, total=   1.9s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.695, total=   2.2s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.753, total=   1.9s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.850, total=   1.9s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.758, total=   1.9s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.714, total=   1.9s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.656, total=   1.9s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.656, total=   1.9s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.693, total=   1.8s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.647, total=   1.8s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.753, total=   1.8s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.695, total=   2.4s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.630, total=   1.9s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.824, total=   1.9s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.732, total=   1.9s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.708, total=   1.9s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.727, total=   1.9s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.773, total=   1.8s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.837, total=   1.8s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.745, total=   2.2s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.695, total=   1.9s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.636, total=   2.0s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.630, total=   1.9s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.418, total=   1.9s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.647, total=   1.8s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:  1.4min finished

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7670231699943543, using {'dropout_rate': 0.0, 'learning_rate': 0.001}
# 0.7670231699943543,0.037720153383631196 with: {'dropout_rate': 0.0, 'learning_rate': 0.001}
# 0.7592139959335327,0.03548229567340402 with: {'dropout_rate': 0.0, 'learning_rate': 0.01}
# 0.731881856918335,0.043928415131059974 with: {'dropout_rate': 0.0, 'learning_rate': 0.1}
# 0.764417290687561,0.03886308113585769 with: {'dropout_rate': 0.1, 'learning_rate': 0.001}
# 0.7553348660469055,0.052478667345966325 with: {'dropout_rate': 0.1, 'learning_rate': 0.01}
# 0.673168671131134,0.025916844334177402 with: {'dropout_rate': 0.1, 'learning_rate': 0.1}
# 0.7266955256462098,0.06403489320522134 with: {'dropout_rate': 0.2, 'learning_rate': 0.001}
# 0.7578983187675477,0.04478046969374677 with: {'dropout_rate': 0.2, 'learning_rate': 0.01}
# 0.6052796900272369,0.09622096854253588 with: {'dropout_rate': 0.2, 'learning_rate': 0.1}

# %% [markdown]
# #### Tuning of Hyperparameters:- Activation Function and Kernel Initializer

# %%
# Defining the model

def create_model(activation_function,init):
    model = Sequential()
    model.add(Dense(8,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(4,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters
activation_function = ['softmax','relu','tanh']
init = ['uniform','normal','zero']

# Make a dictionary of the grid search parameters
param_grids = dict(activation_function = activation_function,init = init)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# [CV]  activation_function=softmax, init=uniform, score=0.351, total=   1.6s
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s remaining:    0.0s
# [CV]  activation_function=softmax, init=uniform, score=0.584, total=   1.6s
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.3s remaining:    0.0s
# [CV]  activation_function=softmax, init=uniform, score=0.630, total=   2.0s
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.3s remaining:    0.0s
# [CV]  activation_function=softmax, init=uniform, score=0.745, total=   1.6s
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    6.9s remaining:    0.0s
# [CV]  activation_function=softmax, init=uniform, score=0.647, total=   1.6s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    8.5s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.649, total=   1.5s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   10.0s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.584, total=   1.6s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   11.6s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.630, total=   1.6s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   13.2s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.745, total=   1.4s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   14.6s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.647, total=   1.4s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.649, total=   1.8s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.416, total=   1.6s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.630, total=   1.6s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.745, total=   1.4s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.647, total=   1.5s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.740, total=   1.6s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.682, total=   1.4s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.760, total=   1.6s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.745, total=   1.4s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.771, total=   1.8s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.766, total=   1.4s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.714, total=   1.5s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.773, total=   1.6s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.797, total=   1.4s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.647, total=   1.4s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.649, total=   1.4s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.584, total=   1.5s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.630, total=   2.0s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.745, total=   1.6s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.647, total=   1.6s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.753, total=   1.6s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.682, total=   1.4s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.747, total=   1.4s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.824, total=   1.4s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.765, total=   1.4s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.747, total=   1.4s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.688, total=   1.9s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.773, total=   1.4s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.830, total=   1.4s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.778, total=   1.5s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.649, total=   1.6s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.584, total=   1.5s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.630, total=   1.4s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.745, total=   1.4s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.647, total=   1.9s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:  1.2min finished

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.763127076625824, using {'activation_function': 'tanh', 'init': 'normal'}
# 0.5914183855056763,0.1313092546244197 with: {'activation_function': 'softmax', 'init': 'uniform'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'softmax', 'init': 'normal'}
# 0.6173924148082733,0.10871275688841411 with: {'activation_function': 'softmax', 'init': 'zero'}
# 0.7396316170692444,0.03090706086724309 with: {'activation_function': 'relu', 'init': 'uniform'}
# 0.7395382404327393,0.05357351760885817 with: {'activation_function': 'relu', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'relu', 'init': 'zero'}
# 0.7540107011795044,0.045193479049117365 with: {'activation_function': 'tanh', 'init': 'uniform'}
# 0.763127076625824,0.04615838902209508 with: {'activation_function': 'tanh', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'tanh', 'init': 'zero'}

# %% [markdown]
# #### Tuning of Hyperparameter :-Number of Neurons in hidden layer

# %%
# Defining the model

def create_model(neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 8,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters

neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of the grid search parameters

param_grids = dict(neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# [CV] ................ neuron1=4, neuron2=2, score=0.740, total=   1.5s
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=2, score=0.701, total=   1.4s
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.9s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=2, score=0.721, total=   1.6s
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.4s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=2, score=0.817, total=   1.4s
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    5.8s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=2, score=0.725, total=   1.5s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    7.4s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.760, total=   1.5s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    8.9s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.682, total=   1.4s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   10.3s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.727, total=   1.9s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   12.3s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.804, total=   1.4s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   13.7s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.771, total=   1.5s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.753, total=   1.4s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.682, total=   1.4s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.734, total=   1.5s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.824, total=   1.4s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.778, total=   1.5s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.766, total=   1.4s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.695, total=   1.8s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.734, total=   1.5s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.824, total=   1.5s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.765, total=   1.5s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.766, total=   1.4s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.708, total=   1.5s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.740, total=   1.4s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.810, total=   1.4s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.771, total=   1.4s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.747, total=   1.9s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.714, total=   1.4s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.753, total=   1.4s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.837, total=   1.5s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.771, total=   1.5s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.753, total=   1.4s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.701, total=   1.4s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.760, total=   1.4s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.817, total=   1.4s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.765, total=   1.8s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.760, total=   1.6s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.708, total=   1.4s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.753, total=   1.4s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.837, total=   1.5s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.758, total=   1.4s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.766, total=   1.5s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.708, total=   1.5s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.760, total=   1.7s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.843, total=   1.4s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.745, total=   1.5s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:  1.1min finished

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7644257783889771, using {'neuron1': 8, 'neuron2': 8}
# 0.7409642815589905,0.04000293633715617 with: {'neuron1': 4, 'neuron2': 2}
# 0.74879891872406,0.04150108298698423 with: {'neuron1': 4, 'neuron2': 4}
# 0.7540276765823364,0.04694657798291982 with: {'neuron1': 4, 'neuron2': 8}
# 0.7566081047058105,0.04237461096982272 with: {'neuron1': 8, 'neuron2': 2}
# 0.7591970205307007,0.03412713188723432 with: {'neuron1': 8, 'neuron2': 4}
# 0.7644257783889771,0.04051439259314147 with: {'neuron1': 8, 'neuron2': 8}
# 0.7591970086097717,0.03676599759364029 with: {'neuron1': 16, 'neuron2': 2}
# 0.763110089302063,0.04145859091454621 with: {'neuron1': 16, 'neuron2': 4}
# 0.7644003033638,0.04427558784171427 with: {'neuron1': 16, 'neuron2': 8}

# %% [markdown]
# #### Training model with optimum values of Hyperparameters

# %%
from sklearn.metrics import classification_report, accuracy_score

# Defining the model

def create_model():
    model = Sequential()
    model.add(Dense(16,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(0.1))
    model.add(Dense(8,input_dim = 16,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(0.0))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.01) #sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Fitting the model

model.fit(X_standardized,y)

# Predicting using trained model

y_predict = model.predict(X_standardized)

# Printing the metrics
print(accuracy_score(y,y_predict))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 0.7916666666666666

# %% [markdown]
# # Hyperparameters all at once

# %% [markdown]
# The hyperparameter optimization was carried out by taking 2 hyperparameters at once. We may have missed the best values. The performance can be further improved by finding the optimum values of hyperparameters all at once given by the code snippet below.
# #### This process is computationally expensive.

# %%
def create_model(learning_rate,dropout_rate,activation_function,init,neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = learning_rate)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0)

# Define the grid search parameters

batch_size = [10,20,40]
epochs = [10,50,100]
learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]
activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']
neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of the grid search parameters

param_grids = dict(batch_size = batch_size,epochs = epochs,learning_rate = learning_rate,dropout_rate = dropout_rate,
                   activation_function = activation_function,init = init,neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)

# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Fitting 5 folds for each of 8748 candidates, totalling 43740 fits
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.649, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.584, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.6s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.630, total=   1.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.4s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.745, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    7.2s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.647, total=   2.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    9.3s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.649, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   11.1s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.584, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   12.9s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.630, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   14.8s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.745, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   16.6s remaining:    0.0s
# Streaming output truncated to the last 5000 lines.
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=100, init=zero, learning_rate=0.1, neuron1=16, neuron2=4, score=0.708, total=  11.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=100, init=zero, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=100, init=zero, learning_rate=0.1, neuron1=16, neuron2=4, score=0.784, total=  11.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=100, init=zero, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=100, init=zero, learning_rate=0.1, neuron1=16, neuron2=4, score=0.752, total=   7.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=100, init=zero, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=100, init=zero, learning_rate=0.1, neuron1=16, neuron2=8, score=0.695, total=  11.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=100, init=zero, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=100, init=zero, learning_rate=0.1, neuron1=16, neuron2=8, score=0.662, total=   7.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=100, init=zero, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=100, init=zero, learning_rate=0.1, neuron1=16, neuron2=8, score=0.766, total=  11.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=100, init=zero, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=100, init=zero, learning_rate=0.1, neuron1=16, neuron2=8, score=0.810, total=   7.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=100, init=zero, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=100, init=zero, learning_rate=0.1, neuron1=16, neuron2=8, score=0.758, total=   7.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.649, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.584, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.630, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.745, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.647, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.649, total=   2.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.584, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.630, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.745, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.647, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8, score=0.649, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8, score=0.584, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8, score=0.630, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8, score=0.745, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8, score=0.647, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2, score=0.649, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2, score=0.584, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2, score=0.630, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2, score=0.745, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2, score=0.647, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4, score=0.649, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4, score=0.584, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4, score=0.630, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4, score=0.745, total=   2.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4, score=0.647, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8, score=0.649, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8, score=0.584, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8, score=0.630, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8, score=0.745, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8, score=0.647, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2, score=0.649, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2, score=0.584, total=   2.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2, score=0.630, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2, score=0.745, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2, score=0.647, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4, score=0.649, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4, score=0.584, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4, score=0.630, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4, score=0.745, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4, score=0.647, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8, score=0.649, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8, score=0.584, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8, score=0.630, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8, score=0.745, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8, score=0.647, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2, score=0.727, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2, score=0.695, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2, score=0.779, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2, score=0.830, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2, score=0.765, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4, score=0.747, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4, score=0.701, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4, score=0.760, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4, score=0.856, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4, score=0.752, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.721, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.727, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.766, total=   2.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.837, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.752, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2, score=0.734, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2, score=0.701, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2, score=0.766, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2, score=0.830, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2, score=0.758, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4, score=0.740, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4, score=0.701, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4, score=0.760, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4, score=0.843, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4, score=0.765, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8, score=0.766, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8, score=0.708, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8, score=0.760, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8, score=0.837, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8, score=0.758, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2, score=0.721, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2, score=0.734, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2, score=0.766, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2, score=0.856, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2, score=0.752, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4, score=0.721, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4, score=0.695, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4, score=0.760, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4, score=0.837, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4, score=0.758, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8, score=0.740, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8, score=0.695, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8, score=0.766, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8, score=0.810, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8, score=0.771, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2, score=0.649, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2, score=0.584, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2, score=0.753, total=   2.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2, score=0.804, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2, score=0.752, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4, score=0.662, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4, score=0.747, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4, score=0.747, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4, score=0.824, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4, score=0.725, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8, score=0.734, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8, score=0.662, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8, score=0.753, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8, score=0.810, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8, score=0.758, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2, score=0.701, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2, score=0.714, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2, score=0.727, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2, score=0.712, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2, score=0.739, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4, score=0.766, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4, score=0.701, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4, score=0.708, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4, score=0.837, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4, score=0.725, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8, score=0.649, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8, score=0.688, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8, score=0.721, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8, score=0.830, total=   2.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8, score=0.758, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2, score=0.714, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2, score=0.688, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2, score=0.630, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2, score=0.745, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2, score=0.758, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4, score=0.721, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4, score=0.675, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4, score=0.727, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4, score=0.830, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4, score=0.732, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8, score=0.708, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8, score=0.714, total=   2.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8, score=0.786, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8, score=0.810, total=   2.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8, score=0.784, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2, score=0.649, total=   2.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2, score=0.584, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2, score=0.630, total=   1.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2, score=0.745, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2, score=0.647, total=   1.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=4, score=0.649, total=   1.9s
# ...
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.647, total=   1.6s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8, score=0.649, total=   1.9s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8, score=0.584, total=   1.9s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8, score=0.630, total=   1.9s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8, score=0.745, total=   1.7s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8, score=0.647, total=   1.9s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2, score=0.649, total=   1.9s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2, score=0.584, total=   1.9s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2, score=0.630, total=   2.4s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2, score=0.745, total=   1.8s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2, score=0.647, total=   1.7s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4, score=0.649, total=   2.0s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4, score=0.584, total=   2.0s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4, score=0.630, total=   2.0s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4, score=0.745, total=   2.0s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4, score=0.647, total=   2.0s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8, score=0.649, total=   2.1s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8, score=0.584, total=   2.1s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8, score=0.630, total=   1.7s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8, score=0.745, total=   2.0s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8, score=0.647, total=   1.7s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2, score=0.649, total=   1.6s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2, score=0.584, total=   2.0s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2, score=0.370, total=   1.7s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2, score=0.745, total=   1.9s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2, score=0.647, total=   2.6s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4, score=0.649, total=   2.0s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4, score=0.584, total=   2.1s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4, score=0.630, total=   2.0s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4, score=0.745, total=   1.8s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4, score=0.647, total=   2.1s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8, score=0.649, total=   1.8s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8, score=0.584, total=   1.7s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8, score=0.630, total=   1.8s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8, score=0.745, total=   2.4s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8, score=0.647, total=   1.7s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2, score=0.747, total=   2.0s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2, score=0.734, total=   2.0s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2, score=0.766, total=   2.1s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2, score=0.830, total=   2.0s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2, score=0.765, total=   1.9s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4, score=0.740, total=   1.8s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4, score=0.734, total=   2.0s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4, score=0.766, total=   2.5s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4, score=0.863, total=   2.0s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4, score=0.745, total=   1.8s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.747, total=   1.8s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.721, total=   2.1s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.766, total=   2.1s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.850, total=   1.7s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.758, total=   1.8s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2, score=0.734, total=   1.9s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2, score=0.714, total=   2.4s
# [CV] activation_function=softmax, batch_size=20, dropout_rate=0.1, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
